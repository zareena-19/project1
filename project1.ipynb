# %% [markdown]
# # Data Manipulation and Analysis using **Pandas**

# %%
import pandas as pd

# %% [markdown]
# # Basic Operations using **pandas**

# %%
df=pd.read_csv("/content/clgplacements.csv")

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.dtypes
# Out:
# Hours     float64
# Scores      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df['Hours']
# Out:
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8
# Name: Hours, dtype: float64

# %%
z=df[['Hours','Scores']]

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Scores'][1:24:2]
# Out:
# 1     47
# 3     75
# 5     20
# 7     60
# 9     25
# 11    62
# 13    42
# 15    95
# 17    24
# 19    69
# 21    54
# 23    76
# Name: Scores, dtype: int64

# %%
df[['Hours','Scores']][0:24:2]
# Out:
#     Hours  Scores
# 0     2.5      21
# 2     3.2      27
# 4     3.5      30
# 6     9.2      88
# 8     8.3      81
# 10    7.7      85
# 12    4.5      41
# 14    1.1      17
# 16    2.5      30
# 18    6.1      67
# 20    2.7      30
# 22    3.8      35

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
df.iloc[0:4]
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75

# %%
df['Scores']>30
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# Name: Scores, dtype: bool

# %%
df[df['Scores']>30]
# Out:
#     Hours  Scores
# 1     5.1      47
# 3     8.5      75
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 15    8.9      95
# 18    6.1      67
# 19    7.4      69
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# # Data Manipulation

# %%
df['new']=df['Hours']+df['Scores']

# %%
df.head()
# Out:
#    Hours  Scores   new
# 0    2.5      21  23.5
# 1    5.1      47  52.1
# 2    3.2      27  30.2
# 3    8.5      75  83.5
# 4    3.5      30  33.5

# %%
df['new2']=df['Scores']+20

# %%
df
# Out:
#     Hours  Scores    new  new2
# 0     2.5      21   23.5    41
# 1     5.1      47   52.1    67
# 2     3.2      27   30.2    47
# 3     8.5      75   83.5    95
# 4     3.5      30   33.5    50
# 5     1.5      20   21.5    40
# 6     9.2      88   97.2   108
# 7     5.5      60   65.5    80
# 8     8.3      81   89.3   101
# 9     2.7      25   27.7    45
# 10    7.7      85   92.7   105
# 11    5.9      62   67.9    82
# 12    4.5      41   45.5    61
# 13    3.3      42   45.3    62
# 14    1.1      17   18.1    37
# 15    8.9      95  103.9   115
# 16    2.5      30   32.5    50
# 17    1.9      24   25.9    44
# 18    6.1      67   73.1    87
# 19    7.4      69   76.4    89
# 20    2.7      30   32.7    50
# 21    4.8      54   58.8    74
# 22    3.8      35   38.8    55
# 23    6.9      76   82.9    96
# 24    7.8      86   93.8   106

# %%
df.dtypes
# Out:
# Hours     float64
# Scores      int64
# new       float64
# new2        int64
# dtype: object

# %%
df=df.drop(['new','new2'],axis=1)

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
df.shape
# Out:
# (25, 2)

# %%
df=df.rename(columns={'Scores': 'Marks Scored'})

# %%
df
# Out:
#     Hours  Marks Scored
# 0     2.5            21
# 1     5.1            47
# 2     3.2            27
# 3     8.5            75
# 4     3.5            30
# 5     1.5            20
# 6     9.2            88
# 7     5.5            60
# 8     8.3            81
# 9     2.7            25
# 10    7.7            85
# 11    5.9            62
# 12    4.5            41
# 13    3.3            42
# 14    1.1            17
# 15    8.9            95
# 16    2.5            30
# 17    1.9            24
# 18    6.1            67
# 19    7.4            69
# 20    2.7            30
# 21    4.8            54
# 22    3.8            35
# 23    6.9            76
# 24    7.8            86

# %%
df['Marks Scored'][0:10]
# Out:
# 0    21
# 1    47
# 2    27
# 3    75
# 4    30
# 5    20
# 6    88
# 7    60
# 8    81
# 9    25
# Name: Marks Scored, dtype: int64

# %%
df.plot(x='Marks Scored',y='Hours',kind='line')
# Out:
# <Axes: xlabel='Marks Scored'>

# %%
df.plot(x='Marks Scored',y='Hours',kind='bar')
# Out:
# <Axes: xlabel='Marks Scored'>

# %%
df['Hours'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Marks Scored'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
